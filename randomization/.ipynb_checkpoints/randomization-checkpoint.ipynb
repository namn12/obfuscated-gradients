# %%
import tensorflow as tf
import numpy as np
import inceptionv3
from utils import *
from defense import *
# Out:
# C:\Users\Nikan\Anaconda3\lib\site-packages\h5py\__init__.py:72: UserWarning: h5py is running against HDF5 1.10.2 when it was built against 1.10.3, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)

# %%
sess = tf.Session() #environment that builds the graph and objects are executed

# %% [markdown]
# # Image and target class

# %% [markdown]
# Choose what you want here.

# %%
orig = load_image('cat.jpg')
TARGET = 924 # guacamole
EPSILON = 8.0/255.0

# %%
lower = np.clip(orig-EPSILON, 0, 1) #makes values below 0 equal to 0 and values above 1 equal to 1
upper = np.clip(orig+EPSILON, 0, 1)

# %% [markdown]
# # Classifier

# %%
x = tf.placeholder(tf.float32, (299, 299, 3)) #inserts placeholder for tensor that will always be fed
x_expanded = tf.expand_dims(x, axis=0) #add one more dimension in the first position
logits, preds = inceptionv3.model(sess, x_expanded) #outputs the probabilities (before softmaxing them)
# Out:
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Restoring parameters from C:\Users\Nikan\Desktop\DL\obfuscated-gradients\randomization\data\inception_v3.ckpt

# %%
probs = tf.nn.softmax(logits) #probabilities after softmax
classify = make_classify(sess, x, probs)

# %%
classify(orig, target_class=TARGET)

# %% [markdown]
# # Failed attack (attempting to transfer)

# %%
loss = tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=one_hot(TARGET, 1000))
grad, = tf.gradients(loss, x)

# %%
# PGD

LR = 0.1

adv = np.copy(orig)
for i in range(10):
    g, p = sess.run([grad, preds], {x: adv})
    print('step %d, pred=%d' % (i, p))
    # step
    adv -= LR * g
    # project
    adv = np.clip(adv, lower, upper)
# Out:
# step 0, pred=282
# step 1, pred=277
# step 2, pred=231
# step 3, pred=272
# step 4, pred=263
# step 5, pred=291
# step 6, pred=924
# step 7, pred=291
# step 8, pred=263
# step 9, pred=924

# %%
cropped_x = defend(x_expanded)
cropped_logits, cropped_preds = inceptionv3.model(sess, cropped_x)
# Out:
# INFO:tensorflow:Scale of 0 disables regularizer.

# %%
cropped_probs = tf.nn.softmax(cropped_logits)
cropped_classify = make_classify(sess, x, cropped_probs)

# %%
cropped_classify(adv, target_class=TARGET)

# %% [markdown]
# # Attack
#
# Using EOT.

# %%
ENSEMBLE_SIZE = 30 # larger sample size -> better gradient estimate

# %%
ensemble_xs = tf.concat([defend(x_expanded) for _ in range(ENSEMBLE_SIZE)], axis=0)
ensemble_logits, ensemble_preds = inceptionv3.model(sess, ensemble_xs)
# Out:
# INFO:tensorflow:Scale of 0 disables regularizer.

# %%
ensemble_labels = tf.tile(tf.expand_dims(tf.one_hot(TARGET, 1000), axis=0), (ensemble_logits.shape[0], 1))
ensemble_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=ensemble_logits, labels=ensemble_labels))
ensemble_grad, = tf.gradients(ensemble_loss, x)

# %%
# PGD

LR = 0.1

adv = np.copy(orig)
for i in range(50):
    g, p = sess.run([ensemble_grad, ensemble_preds], {x: adv})
    if i % 10 == 0:
        print('step %d, preds=%s' % (i, p))
    # step
    adv -= LR * g
    # project
    adv = np.clip(adv, lower, upper)
# Out:
# step 0, preds=[287 287 287 282 287 287 287 287 287 287 287 282 274 287 287 278 287 282
#  277 287 287 287 287 287 287 287 287 287 287 286]
# step 10, preds=[924 924 263 924 924 157 924 924 728 924 282 924 263 157 924 924 157 274
#  924 924 728 924 282 924 924 728 924 263 287 924]
# step 20, preds=[924 924 924 924 924 924 924 924 924 924 924 924 924 924 924 924 924 924
#  924 924 924 924 924 924 924 924 924 924 924 924]
# step 30, preds=[924 924 924 924 924 924 924 924 924 924 924 924 924 924 924 924 924 924
#  924 924 924 924 924 924 924 924 924 924 924 924]
# step 40, preds=[924 924 924 924 924 924 924 924 924 924 924 924 924 924 924 924 924 924
#  924 924 924 924 924 924 924 924 924 924 924 924]

# %%
plt.imshow(adv)

# %%
cropped_classify(adv, target_class=TARGET)
